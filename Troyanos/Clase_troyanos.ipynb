# %%
import os
import requests
import pandas as pd
import io
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
from dask import delayed, compute
from dask.distributed import Client
import warnings
from PIL import GimpGradientFile
warnings.filterwarnings('ignore')

# %%
class SistemaPlanetario:
    def __init__(self, m1, m2, d):
        self.m1 = m1 * 1.989E30  # masa estrella en kg
        self.m2 = m2 * 5.972E24  # masa planeta en kg (Ingresa en Masas Terrestres)
        self.mu2 = self.m2 / (self.m1 + self.m2)
        self.mu1 = 1.0 - self.mu2
        self.distanciaPrimarios = d * 1.496E8  # AU -> km

        # Parámetros de simulación
        self.m = 100
        self.n = self.m
        self.a = 0.2
        self.b = self.a
        self.tiempo = 500
        self.M = 1000

        # Listas de resultados
        self.estable_x = []
        self.estable_y = []
        self.inestable_x = []
        self.inestable_y = []
        self.colision_m1x = []
        self.colision_m1y = []
        self.colision_m2x = []
        self.colision_m2y = []

    # Función del sistema
    def f1(self, t, v):
        x, y, xp, yp = v
        r1p = ((x + self.mu2)**2 + y**2)**(-3/2.)
        r2p = ((x - self.mu1)**2 + y**2)**(-3/2.)
        dv1 = xp + y
        dv2 = yp - x
        dv3 = yp - self.mu1 * (x + self.mu2) * r1p - self.mu2 * (x - self.mu1) * r2p
        dv4 = -xp - self.mu1 * y * r1p - self.mu2 * y * r2p
        return np.array([dv1, dv2, dv3, dv4])

    # Hamiltoniano
    def ham(self, s):
        x, y, px, py = s
        r1p = ((x + self.mu2)**2 + y**2)**0.5
        r2p = ((x - self.mu1)**2 + y**2)**0.5
        return (0.5 * (px**2 + py**2) + y * px - x * py 
                - self.mu1 / r1p - self.mu2 / r2p)

    # Runge-Kutta de 6to orden
    def RungeKutaS6(self, t0, tn, x0, n):
        t = np.linspace(t0, tn, n + 1)
        m = len(x0)
        x = np.zeros((m, n + 1))
        x[:, 0] = x0
        h = (tn - t0) / n
        TOL = 0.01

        for i in range(1, n + 1):
            k1 = self.f1(t[i-1], x[:, i-1])
            k2 = self.f1(t[i-1] + h*(1/3.), x[:, i-1] + (1/3.)*k1*h)
            k3 = self.f1(t[i-1] + h*(2/3.), x[:, i-1] + (2/3)*k2*h)
            k4 = self.f1(t[i-1] + h*(1/3), x[:, i-1] + (1/12)*k1*h + (1/3)*k2*h - (1/12)*h*k3)
            k5 = self.f1(t[i-1] + h*(5/6.), x[:, i-1] + (25/48.)*k1*h - (55/24.)*k2*h + (35/48.)*k3*h + k4*(15/8.)*h)
            k6 = self.f1(t[i-1] + h*(1/6.), x[:, i-1] + (3/20)*k1*h - (11/24)*k2*h - (1/8)*k3*h + (1/2)*k4*h + (1/10)*h*k5)
            k7 = self.f1(t[i], x[:, i-1] - (261/260)*k1*h + (33/13)*k2*h + (43/156)*k3*h - (118/39)*k4*h + (32/195)*k5*h + (80/39)*k6*h)
            x[:, i] = x[:, i-1] + ((13/200)*k1 + (11/40.)*k3 + (11/40.)*k4 + (4/25)*k5 + (4/25)*k6 + (13/200)*k7)*h

            if x[1, i] < 0:
                j = 1
                break
            elif (np.abs(x[0, i] - self.mu2) < TOL and np.abs(x[1, i]) < TOL):
                j = 2
                break
            elif (np.abs(x[0, i] - self.mu1) < TOL and np.abs(x[1, i]) < TOL):
                j = 3
                break
        else:
            j = 4

        return j, x

    # Crear malla de puntos
    def malla(self, m, n, a, b):
        x = np.linspace(-a, a, n)
        y = np.linspace(-b, b, m)
        xx, yy = np.meshgrid(x, y)
        points = np.c_[xx.ravel(), yy.ravel()]
        return points

    # Simulación con Dask
    def simular(self, client=None, chunk_size=100):
        points = self.malla(self.m, self.n, self.a, self.b)
        total_points = len(points)

        @delayed
        def simular_lote(lote):
            resultados_lote = []
            for point in lote:
                x0 = 0.5 - self.mu2 + point[0]
                y0 = (3**0.5) * 0.5 + point[1]
                f0 = [x0, y0, -y0, x0]
                j, x = self.RungeKutaS6(0, self.tiempo, f0, self.M)
                resultados_lote.append((j, x0, y0))
            return resultados_lote

        lotes = [points[i:i+chunk_size] for i in range(0, total_points, chunk_size)]
        tareas = [simular_lote(lote) for lote in lotes]

        if client is not None:
            resultados = client.compute(tareas, sync=True)
        else:
            resultados = compute(*tareas)

        for lote in resultados:
            for j, x0, y0 in lote:
                if j == 1:
                    self.inestable_x.append(x0)
                    self.inestable_y.append(y0)
                elif j == 2:
                    self.colision_m1x.append(x0)
                    self.colision_m1y.append(y0)
                elif j == 3:
                    self.colision_m2x.append(x0)
                    self.colision_m2y.append(y0)
                else:
                    self.estable_x.append(x0)
                    self.estable_y.append(y0)

    # Guardar resultados y graficar (Correctamente indentado)
    def guardar_resultados(self, directorio, nombre="zonas", graficar=True):
        os.makedirs(directorio, exist_ok=True)

        Table([self.estable_x, self.estable_y], names=('x', 'y')).write(
            os.path.join(directorio, f"{nombre}_estables.txt"),
            format='ascii.commented_header', overwrite=True)
        Table([self.inestable_x, self.inestable_y], names=('x', 'y')).write(
            os.path.join(directorio, f"{nombre}_inestables.txt"),
            format='ascii.commented_header', overwrite=True)
        Table([self.colision_m1x, self.colision_m1y], names=('x', 'y')).write(
            os.path.join(directorio, f"{nombre}_colision_m1.txt"),
            format='ascii.commented_header', overwrite=True)
        Table([self.colision_m2x, self.colision_m2y], names=('x', 'y')).write(
            os.path.join(directorio, f"{nombre}_colision_m2.txt"),
            format='ascii.commented_header', overwrite=True)

        estable_x = len(self.estable_x)
        inestable_x = len(self.inestable_x)
        colision_m1 = len(self.colision_m1x)
        colision_m2 = len(self.colision_m2x)

        deltaA = (2 * self.a) / self.n
        deltaB = (2 * self.b) / self.m
        deltaKmA = deltaA * self.distanciaPrimarios
        deltaKmB = deltaB * self.distanciaPrimarios
        area = deltaKmA * deltaKmB

        area_est = area * estable_x
        area_inest = area * inestable_x
        area_colM1 = area * colision_m1
        area_colM2 = area * colision_m2

        resumen_path = os.path.join(directorio, f"{nombre}_resumen.txt")
        with open(resumen_path, "w", encoding='utf-8') as f:
            f.write("=== Resumen de resultados ===\n")
            f.write(f"Total estables: {estable_x}\n")
            f.write(f"Total inestables: {inestable_x}\n")
            f.write(f"Total colisión m1: {colision_m1}\n")
            f.write(f"Total colisión m2: {colision_m2}\n\n")
            f.write("=== Áreas en km² ===\n")
            f.write("Área total de la grilla: {:.2e} km²\n".format(area))
            f.write("Área estable: {:.2e} km²\n".format(area_est))
            f.write("Área inestable: {:.2e} km²\n".format(area_inest))
            f.write("Área de colisión con m1: {:.2e} km²\n".format(area_colM1))
            f.write("Área de colisión con m2: {:.2e} km²\n".format(area_colM2))

        if graficar:
            plt.scatter(self.estable_x, self.estable_y, color='blue', s=10, label='Estables')
            plt.scatter(self.inestable_x, self.inestable_y, color='silver', s=10, label='Inestables')
            plt.scatter(self.colision_m1x, self.colision_m1y, color='green', s=10, label='Colisión m1')
            plt.scatter(self.colision_m2x, self.colision_m2y, color='brown', s=10, label='Colisión m2')
            plt.scatter(0.5 - self.mu2, np.sqrt(3)/2, marker='v', color='red', label='L4')
            plt.xlabel('x [adim]')
            plt.ylabel('y [adim]')
            plt.legend()
            plt.title(f"Mapa de estabilidad - {nombre}")
            ruta_pdf = os.path.join(directorio, f"{nombre}_mapa_estabilidad.pdf")
            plt.savefig(ruta_pdf, format="pdf", bbox_inches="tight")
            plt.close()

# %%
def ejecutar_pipeline_completo(tipo_espectral, masa_min, masa_max, client):
    """
    Extrae datos de la NASA, los limpia, crea la estructura de carpetas
    e inyecta los datos directamente en la simulación astrofísica.
    """
    url_base = "https://exoplanetarchive.ipac.caltech.edu/TAP/sync"
    tipo_esp_sql = tipo_espectral.replace("'", "''")
    
    query = f"""
    SELECT hostname AS estrella, sy_pnum, sy_dist, st_spectype, st_teff, st_rad, st_mass, 
           st_teff_reflink, pl_name, pl_orbper, pl_orbsmax, pl_rade, pl_bmasse, pl_bmassj, pl_msinij
    FROM pscomppars
    WHERE sy_pnum BETWEEN 3 AND 8
      AND st_spectype LIKE '%{tipo_esp_sql}%'
      AND (pl_bmassj BETWEEN {masa_min} AND {masa_max} OR pl_msinij BETWEEN {masa_min} AND {masa_max})
    """
    
    print(f"📡 Consultando base de datos NASA... (Espectro: {tipo_espectral})")
    respuesta = requests.get(url_base, params={"query": query, "format": "csv"})
    if respuesta.status_code != 200: 
        print("Error al contactar la API.")
        return
    
    df_completo = pd.read_csv(io.StringIO(respuesta.text))
    if df_completo.empty:
        print("No se encontraron sistemas con esos criterios.")
        return
    
    # LIMPIEZA: Quedarse con el paper más reciente por estrella
    df_completo['Año_Ref'] = df_completo['st_teff_reflink'].str.extract(r'(\d{4})').astype(float)
    df_star = df_completo.sort_values(by=['estrella', 'Año_Ref'], ascending=[True, False]).drop_duplicates(subset=['estrella'], keep='first')

    # CREACIÓN DEL DIRECTORIO BASE
    base_dir = f"Resultados_Estrellas_{tipo_espectral}"
    os.makedirs(base_dir, exist_ok=True)
    print(f" Directorio raíz creado: {base_dir}")
    
    # ITERAR SOBRE CADA ESTRELLA ENCONTRADA
    for _, star in df_star.iterrows():
        est_nombre = star['estrella'].replace(" ", "_")
        m_estrella = star['st_mass']
        
        if pd.isna(m_estrella): continue # Saltamos si no hay masa estelar conocida
            
        print(f"\n Procesando sistema: {est_nombre} (Masa: {m_estrella} M_sol)")
        
        # Filtrar planetas correspondientes a esta estrella
        planets = df_completo[df_completo['estrella'] == star['estrella']]
        
        for _, pl in planets.iterrows():
            distancia = pl['pl_orbsmax']
            
            # FILTRO: Necesitamos la distancia para simular
            if pd.isna(distancia): 
                print(f"  [!] Saltando {pl['pl_name']} (Falta parámetro de distancia orbital)")
                continue
            
            # CONVERSIÓN A MASAS TERRESTRES
            # Priorizamos la masa en tierras, si no, convertimos de Júpiter a Tierras (* 317.828)
            if pd.notna(pl['pl_bmasse']):
                masa_tierra = pl['pl_bmasse']
            elif pd.notna(pl['pl_bmassj']):
                masa_tierra = pl['pl_bmassj'] * 317.828
            elif pd.notna(pl['pl_msinij']):
                masa_tierra = pl['pl_msinij'] * 317.828
            else:
                print(f"  [!] Saltando {pl['pl_name']} (Falta parámetro de masa)")
                continue
                
            # CREACIÓN DE DIRECTORIO PARA EL PLANETA
            nombre_planeta_limpio = pl['pl_name'].replace(" ", "_")
            path = os.path.join(base_dir, est_nombre, nombre_planeta_limpio)
            os.makedirs(path, exist_ok=True)
            
            # EXPORTAR README DEL PLANETA
            readme_path = os.path.join(path, f"README_{nombre_planeta_limpio}.txt")
            with open(readme_path, "w", encoding="utf-8") as f:
                f.write(f"SISTEMA: {star['estrella']}\n")
                f.write(f"PLANETA: {pl['pl_name']}\n")
                f.write("=" * 40 + "\n")
                f.write(f"Masa de la Estrella (Masas Solares): {m_estrella}\n")
                f.write(f"Temperatura Estrella (K): {star['st_teff']}\n")
                f.write(f"Masa del Planeta (Masas Terrestres): {masa_tierra:.4f}\n")
                f.write(f"Semi-eje mayor de la órbita (UA): {distancia}\n")
                f.write(f"Periodo Orbital (días): {pl['pl_orbper']}\n")
                f.write(f"Referencia: {star['st_teff_reflink']}\n")

            # --- SIMULACIÓN FÍSICA ---
            print(f"  -> Simulando planeta {pl['pl_name']} ...")
            sistema = SistemaPlanetario(m_estrella, masa_tierra, distancia)
            sistema.simular(client=client)
            sistema.guardar_resultados(path, nombre=f"{est_nombre}_{nombre_planeta_limpio}")
            print(f"  -> ✔️ Resultados guardados en: {path}")

# %%
if __name__ == "__main__":
    # 1. Configuración de Filtros de Investigación
    ESPECTRO = "F"
    M_MIN_JUP = 0.0001
    M_MAX_JUP = 2.0
    
    # 2. Iniciar cliente de procesamiento paralelo Dask
    print("Iniciando workers de Dask...")
    cliente_dask = Client(n_workers=4)
    
    # 3. Lanzar pipeline
    ejecutar_pipeline_completo(ESPECTRO, M_MIN_JUP, M_MAX_JUP, client=cliente_dask)
# Out:
# Iniciando workers de Dask...
# 📡 Consultando base de datos NASA... (Espectro: F)
#  Directorio raíz creado: Resultados_Estrellas_F
#
#  Procesando sistema: DMPP-1 (Masa: 1.21 M_sol)
#   -> Simulando planeta DMPP-1 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\DMPP-1\DMPP-1_e
#   -> Simulando planeta DMPP-1 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\DMPP-1\DMPP-1_c
#   -> Simulando planeta DMPP-1 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\DMPP-1\DMPP-1_b
#   -> Simulando planeta DMPP-1 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\DMPP-1\DMPP-1_d
#
#  Procesando sistema: DMPP-2 (Masa: 1.41 M_sol)
#   -> Simulando planeta DMPP-2 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\DMPP-2\DMPP-2_c
#   -> Simulando planeta DMPP-2 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\DMPP-2\DMPP-2_b
#   -> Simulando planeta DMPP-2 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\DMPP-2\DMPP-2_d
#
#  Procesando sistema: HD_142 (Masa: 1.21 M_sol)
#   -> Simulando planeta HD 142 A d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HD_142\HD_142_A_d
#   -> Simulando planeta HD 142 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HD_142\HD_142_b
#
#  Procesando sistema: HD_22946 (Masa: 1.098 M_sol)
#   -> Simulando planeta HD 22946 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HD_22946\HD_22946_d
#   -> Simulando planeta TOI-411 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HD_22946\TOI-411_c
#   -> Simulando planeta TOI-411 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HD_22946\TOI-411_b
#
#  Procesando sistema: HD_28109 (Masa: 1.227 M_sol)
#   -> Simulando planeta HD 28109 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HD_28109\HD_28109_c
#   -> Simulando planeta HD 28109 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HD_28109\HD_28109_b
#   -> Simulando planeta HD 28109 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HD_28109\HD_28109_d
#
#  Procesando sistema: HD_50554 (Masa: 1.04 M_sol)
#   -> Simulando planeta HD 50554 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HD_50554\HD_50554_c
#   -> Simulando planeta HD 50554 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HD_50554\HD_50554_d
#
#  Procesando sistema: HD_73344 (Masa: 1.19 M_sol)
#   -> Simulando planeta HD 73344 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HD_73344\HD_73344_b
#   -> Simulando planeta HD 73344 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HD_73344\HD_73344_c
#
#  Procesando sistema: HIP_41378 (Masa: 1.22 M_sol)
#   [!] Saltando HIP 41378 g (Falta parámetro de distancia orbital)
#   -> Simulando planeta HIP 41378 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HIP_41378\HIP_41378_b
#   -> Simulando planeta HIP 41378 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HIP_41378\HIP_41378_c
#   -> Simulando planeta HIP 41378 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HIP_41378\HIP_41378_d
#   -> Simulando planeta HIP 41378 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HIP_41378\HIP_41378_e
#   -> Simulando planeta HIP 41378 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HIP_41378\HIP_41378_f
#
#  Procesando sistema: HR_858 (Masa: 1.204 M_sol)
#   -> Simulando planeta HR 858 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HR_858\HR_858_b
#   -> Simulando planeta HR 858 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HR_858\HR_858_d
#   -> Simulando planeta HR 858 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\HR_858\HR_858_c
#
#  Procesando sistema: Kepler-25 (Masa: 1.165 M_sol)
#   -> Simulando planeta Kepler-25 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\Kepler-25\Kepler-25_c
#   -> Simulando planeta Kepler-25 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\Kepler-25\Kepler-25_b
#   -> Simulando planeta Kepler-25 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\Kepler-25\Kepler-25_d
#
#  Procesando sistema: TOI-201 (Masa: 1.32 M_sol)
#   -> Simulando planeta TOI-201 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\TOI-201\TOI-201_b
#   -> Simulando planeta TOI-201 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\TOI-201\TOI-201_d
#
#  Procesando sistema: ups_And (Masa: 1.3 M_sol)
#   -> Simulando planeta ups And b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\ups_And\ups_And_b
#   -> Simulando planeta ups And c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_F\ups_And\ups_And_c

# %%
if __name__ == "__main__":
    # 1. Configuración de Filtros de Investigación
    ESPECTRO = "G"
    M_MIN_JUP = 0.0001
    M_MAX_JUP = 2.0
    
    # 2. Iniciar cliente de procesamiento paralelo Dask
    print("Iniciando workers de Dask...")
    cliente_dask = Client(n_workers=4)
    
    # 3. Lanzar pipeline
    ejecutar_pipeline_completo(ESPECTRO, M_MIN_JUP, M_MAX_JUP, client=cliente_dask)
# Out:
# Iniciando workers de Dask...
# 📡 Consultando base de datos NASA... (Espectro: G)
#  Directorio raíz creado: Resultados_Estrellas_G
#
#  Procesando sistema: 47_UMa (Masa: 1.06 M_sol)
#   -> Simulando planeta 47 UMa d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\47_UMa\47_UMa_d
#   -> Simulando planeta 47 UMa c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\47_UMa\47_UMa_c
#
#  Procesando sistema: 55_Cnc (Masa: 1.015 M_sol)
#   -> Simulando planeta 55 Cnc b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\55_Cnc\55_Cnc_b
#   -> Simulando planeta 55 Cnc c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\55_Cnc\55_Cnc_c
#   -> Simulando planeta 55 Cnc e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\55_Cnc\55_Cnc_e
#   -> Simulando planeta 55 Cnc f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\55_Cnc\55_Cnc_f
#
#  Procesando sistema: 61_Vir (Masa: 0.942 M_sol)
#   -> Simulando planeta 61 Vir b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\61_Vir\61_Vir_b
#   -> Simulando planeta 61 Vir c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\61_Vir\61_Vir_c
#   -> Simulando planeta 61 Vir d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\61_Vir\61_Vir_d
#
#  Procesando sistema: CoRoT-7 (Masa: 0.915 M_sol)
#   -> Simulando planeta CoRoT-7 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\CoRoT-7\CoRoT-7_b
#   -> Simulando planeta CoRoT-7 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\CoRoT-7\CoRoT-7_c
#   [!] Saltando CoRoT-7 d (Falta parámetro de distancia orbital)
#
#  Procesando sistema: EPIC_249893012 (Masa: 1.05 M_sol)
#   -> Simulando planeta EPIC 249893012 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\EPIC_249893012\EPIC_249893012_b
#   -> Simulando planeta EPIC 249893012 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\EPIC_249893012\EPIC_249893012_c
#   -> Simulando planeta EPIC 249893012 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\EPIC_249893012\EPIC_249893012_d
#
#  Procesando sistema: HD_10180 (Masa: 1.06 M_sol)
#   -> Simulando planeta HD 10180 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_10180\HD_10180_c
#   -> Simulando planeta HD 10180 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_10180\HD_10180_d
#   -> Simulando planeta HD 10180 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_10180\HD_10180_e
#   -> Simulando planeta HD 10180 h ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_10180\HD_10180_h
#   -> Simulando planeta HD 10180 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_10180\HD_10180_f
#   -> Simulando planeta HD 10180 g ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_10180\HD_10180_g
#
#  Procesando sistema: HD_108236 (Masa: 0.869 M_sol)
#   -> Simulando planeta HD 108236 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_108236\HD_108236_f
#   -> Simulando planeta TOI-1233.01 ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_108236\TOI-1233.01
#   -> Simulando planeta HD 108236 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_108236\HD_108236_b
#   -> Simulando planeta HD 108236 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_108236\HD_108236_e
#   -> Simulando planeta HD 108236 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_108236\HD_108236_c
#
#  Procesando sistema: HD_11506 (Masa: 1.22 M_sol)
#   -> Simulando planeta HD 11506 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_11506\HD_11506_c
#
#  Procesando sistema: HD_125612 (Masa: 1.05 M_sol)
#   -> Simulando planeta HD 125612 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_125612\HD_125612_c
#
#  Procesando sistema: HD_133131_A (Masa: 0.95 M_sol)
#   -> Simulando planeta HD 133131 A b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_133131_A\HD_133131_A_b
#   -> Simulando planeta HD 133131 A c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_133131_A\HD_133131_A_c
#
#  Procesando sistema: HD_134606 (Masa: 1.046 M_sol)
#   -> Simulando planeta HD 134606 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_134606\HD_134606_c
#   -> Simulando planeta HD 134606 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_134606\HD_134606_b
#   -> Simulando planeta HD 134606 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_134606\HD_134606_d
#   -> Simulando planeta HD 134606 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_134606\HD_134606_f
#   -> Simulando planeta HD 134606 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_134606\HD_134606_e
#
#  Procesando sistema: HD_136352 (Masa: 0.87 M_sol)
#   -> Simulando planeta HD 136352 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_136352\HD_136352_c
#   -> Simulando planeta HD 136352 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_136352\HD_136352_b
#   -> Simulando planeta HD 136352 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_136352\HD_136352_d
#
#  Procesando sistema: HD_158259 (Masa: 1.08 M_sol)
#   [!] Saltando HD 158259 b (Falta parámetro de distancia orbital)
#   [!] Saltando HD 158259 d (Falta parámetro de distancia orbital)
#   [!] Saltando HD 158259 f (Falta parámetro de distancia orbital)
#   [!] Saltando HD 158259 e (Falta parámetro de distancia orbital)
#   [!] Saltando HD 158259 c (Falta parámetro de distancia orbital)
#
#  Procesando sistema: HD_160691 (Masa: 1.13 M_sol)
#   -> Simulando planeta HD 160691 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_160691\HD_160691_b
#   -> Simulando planeta HD 160691 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_160691\HD_160691_d
#   -> Simulando planeta HD 160691 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_160691\HD_160691_e
#
#  Procesando sistema: HD_164922 (Masa: 0.921146 M_sol)
#   -> Simulando planeta HD 164922 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_164922\HD_164922_c
#   -> Simulando planeta HD 164922 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_164922\HD_164922_b
#   -> Simulando planeta HD 164922 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_164922\HD_164922_d
#   -> Simulando planeta HD 164922 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_164922\HD_164922_e
#
#  Procesando sistema: HD_190360 (Masa: 0.996 M_sol)
#   -> Simulando planeta HD 190360 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_190360\HD_190360_b
#   -> Simulando planeta HD 190360 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_190360\HD_190360_c
#   -> Simulando planeta HD 190360 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_190360\HD_190360_d
#
#  Procesando sistema: HD_191939 (Masa: 0.81 M_sol)
#   -> Simulando planeta HD 191939 g ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_191939\HD_191939_g
#   -> Simulando planeta HD 191939 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_191939\HD_191939_b
#   -> Simulando planeta HD 191939 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_191939\HD_191939_e
#   -> Simulando planeta HD 191939 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_191939\HD_191939_c
#   -> Simulando planeta HD 191939 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_191939\HD_191939_d
#
#  Procesando sistema: HD_204313 (Masa: 1.03 M_sol)
#   -> Simulando planeta HD 204313 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_204313\HD_204313_c
#
#  Procesando sistema: HD_20782 (Masa: 1.04 M_sol)
#   -> Simulando planeta HD 20782 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_20782\HD_20782_b
#
#  Procesando sistema: HD_20794 (Masa: 0.79 M_sol)
#   -> Simulando planeta HD 20794 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_20794\HD_20794_f
#   -> Simulando planeta HD 20794 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_20794\HD_20794_d
#   -> Simulando planeta HD 20794 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_20794\HD_20794_b
#   -> Simulando planeta HD 20794 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_20794\HD_20794_e
#
#  Procesando sistema: HD_224018 (Masa: 1.013 M_sol)
#   -> Simulando planeta HD 224018 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_224018\HD_224018_b
#   -> Simulando planeta HD 224018 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_224018\HD_224018_d
#   -> Simulando planeta HD 224018 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_224018\HD_224018_c
#
#  Procesando sistema: HD_28471 (Masa: 0.98 M_sol)
#   -> Simulando planeta HD 28471 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_28471\HD_28471_b
#   -> Simulando planeta HD 28471 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_28471\HD_28471_c
#   -> Simulando planeta HD 28471 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_28471\HD_28471_d
#
#  Procesando sistema: HD_31527 (Masa: 0.96 M_sol)
#   -> Simulando planeta HD 31527 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_31527\HD_31527_c
#   -> Simulando planeta HD 31527 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_31527\HD_31527_b
#   -> Simulando planeta HD 31527 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_31527\HD_31527_d
#
#  Procesando sistema: HD_34445 (Masa: 1.07 M_sol)
#   -> Simulando planeta HD 34445 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_34445\HD_34445_c
#   -> Simulando planeta HD 34445 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_34445\HD_34445_d
#   -> Simulando planeta HD 34445 g ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_34445\HD_34445_g
#   -> Simulando planeta HD 34445 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_34445\HD_34445_b
#   -> Simulando planeta HD 34445 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_34445\HD_34445_f
#   -> Simulando planeta HD 34445 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_34445\HD_34445_e
#
#  Procesando sistema: HD_37124 (Masa: 0.85 M_sol)
#   -> Simulando planeta HD 37124 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_37124\HD_37124_d
#   -> Simulando planeta HD 37124 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_37124\HD_37124_b
#   -> Simulando planeta HD 37124 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_37124\HD_37124_c
#
#  Procesando sistema: HD_39091 (Masa: 1.07 M_sol)
#   -> Simulando planeta pi Men d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_39091\pi_Men_d
#   -> Simulando planeta pi Men c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_39091\pi_Men_c
#
#  Procesando sistema: HD_63433 (Masa: 0.99 M_sol)
#   -> Simulando planeta HD 63433 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_63433\HD_63433_b
#   -> Simulando planeta HD 63433 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_63433\HD_63433_c
#   -> Simulando planeta HD 63433 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_63433\HD_63433_d
#
#  Procesando sistema: HD_93385 (Masa: 1.04 M_sol)
#   -> Simulando planeta HD 93385 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_93385\HD_93385_c
#   -> Simulando planeta HD 93385 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_93385\HD_93385_d
#   -> Simulando planeta HD 93385 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_93385\HD_93385_b
#
#  Procesando sistema: HD_96700 (Masa: 0.89 M_sol)
#   -> Simulando planeta HD 96700 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_96700\HD_96700_b
#   -> Simulando planeta HD 96700 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_96700\HD_96700_c
#   -> Simulando planeta HD 96700 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HD_96700\HD_96700_d
#
#  Procesando sistema: HIP_14810 (Masa: 1.01 M_sol)
#   -> Simulando planeta HIP 14810 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HIP_14810\HIP_14810_d
#   -> Simulando planeta HIP 14810 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\HIP_14810\HIP_14810_c
#
#  Procesando sistema: K2-138 (Masa: 0.935 M_sol)
#   -> Simulando planeta K2-138 g ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-138\K2-138_g
#   -> Simulando planeta K2-138 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-138\K2-138_c
#   -> Simulando planeta K2-138 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-138\K2-138_d
#   -> Simulando planeta K2-138 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-138\K2-138_e
#   -> Simulando planeta K2-138 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-138\K2-138_f
#   -> Simulando planeta K2-138 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-138\K2-138_b
#
#  Procesando sistema: K2-157 (Masa: 0.89 M_sol)
#   -> Simulando planeta K2-157 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-157\K2-157_d
#   -> Simulando planeta K2-157 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-157\K2-157_b
#   -> Simulando planeta K2-157 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-157\K2-157_c
#
#  Procesando sistema: K2-19 (Masa: 0.892 M_sol)
#   -> Simulando planeta K2-19 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-19\K2-19_c
#   -> Simulando planeta K2-19 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-19\K2-19_d
#   -> Simulando planeta K2-19 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-19\K2-19_b
#
#  Procesando sistema: K2-32 (Masa: 0.83 M_sol)
#   -> Simulando planeta K2-32 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-32\K2-32_b
#   -> Simulando planeta K2-32 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-32\K2-32_e
#   -> Simulando planeta K2-32 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-32\K2-32_c
#   -> Simulando planeta K2-32 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-32\K2-32_d
#
#  Procesando sistema: K2-37 (Masa: 0.84 M_sol)
#   -> Simulando planeta K2-37 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-37\K2-37_c
#   -> Simulando planeta K2-37 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-37\K2-37_b
#   -> Simulando planeta K2-37 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\K2-37\K2-37_d
#
#  Procesando sistema: KOI-142 (Masa: 0.99 M_sol)
#   -> Simulando planeta KOI-142 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\KOI-142\KOI-142_c
#   -> Simulando planeta KOI-142 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\KOI-142\KOI-142_b
#
#  Procesando sistema: Kepler-129 (Masa: 1.178 M_sol)
#   -> Simulando planeta Kepler-129 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\Kepler-129\Kepler-129_b
#   -> Simulando planeta Kepler-129 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\Kepler-129\Kepler-129_c
#
#  Procesando sistema: Kepler-82 (Masa: 0.91 M_sol)
#   -> Simulando planeta Kepler-82 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\Kepler-82\Kepler-82_f
#   -> Simulando planeta Kepler-82 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\Kepler-82\Kepler-82_e
#   -> Simulando planeta Kepler-82 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\Kepler-82\Kepler-82_b
#   -> Simulando planeta Kepler-82 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\Kepler-82\Kepler-82_c
#
#  Procesando sistema: TOI-1117 (Masa: 0.97 M_sol)
#   -> Simulando planeta TOI-1117 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-1117\TOI-1117_b
#   -> Simulando planeta TOI-1117 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-1117\TOI-1117_c
#   -> Simulando planeta TOI-1117 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-1117\TOI-1117_d
#
#  Procesando sistema: TOI-1203 (Masa: 0.886 M_sol)
#   [!] Saltando TOI-1203 e (Falta parámetro de distancia orbital)
#   -> Simulando planeta TOI-1203.01 ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-1203\TOI-1203.01
#   -> Simulando planeta TOI-1203 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-1203\TOI-1203_b
#   [!] Saltando TOI-1203 c (Falta parámetro de distancia orbital)
#
#  Procesando sistema: TOI-451 (Masa: 0.93 M_sol)
#   -> Simulando planeta TOI-451 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-451\TOI-451_b
#   -> Simulando planeta TOI-451 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-451\TOI-451_c
#   -> Simulando planeta TOI-451 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-451\TOI-451_d
#
#  Procesando sistema: TOI-561 (Masa: 0.806 M_sol)
#   -> Simulando planeta TOI-561 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-561\TOI-561_b
#   -> Simulando planeta TOI-561 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-561\TOI-561_c
#   -> Simulando planeta TOI-561 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-561\TOI-561_d
#   -> Simulando planeta TOI-561 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-561\TOI-561_e
#
#  Procesando sistema: TOI-7510 (Masa: 1.063 M_sol)
#   -> Simulando planeta TOI-7510 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-7510\TOI-7510_c
#   -> Simulando planeta TOI-7510 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-7510\TOI-7510_b
#   -> Simulando planeta TOI-7510 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\TOI-7510\TOI-7510_d
#
#  Procesando sistema: WASP-47 (Masa: 1.058 M_sol)
#   -> Simulando planeta WASP-47 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\WASP-47\WASP-47_b
#   -> Simulando planeta WASP-47 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\WASP-47\WASP-47_c
#   -> Simulando planeta WASP-47 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\WASP-47\WASP-47_d
#   -> Simulando planeta WASP-47 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\WASP-47\WASP-47_e
#
#  Procesando sistema: XO-2_N (Masa: 0.96 M_sol)
#   -> Simulando planeta XO-2 N b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\XO-2_N\XO-2_N_b
#
#  Procesando sistema: XO-2_S (Masa: 0.98 M_sol)
#   -> Simulando planeta XO-2 S b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\XO-2_S\XO-2_S_b
#   -> Simulando planeta XO-2 S c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\XO-2_S\XO-2_S_c
#
#  Procesando sistema: rho_CrB (Masa: 1.0 M_sol)
#   -> Simulando planeta rho CrB c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\rho_CrB\rho_CrB_c
#   -> Simulando planeta rho CrB e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\rho_CrB\rho_CrB_e
#   -> Simulando planeta rho CrB b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\rho_CrB\rho_CrB_b
#
#  Procesando sistema: tau_Cet (Masa: 0.783 M_sol)
#   -> Simulando planeta tau Cet g ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\tau_Cet\tau_Cet_g
#   -> Simulando planeta tau Cet f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\tau_Cet\tau_Cet_f
#   -> Simulando planeta tau Cet h ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_G\tau_Cet\tau_Cet_h

# %%
if __name__ == "__main__":
    # 1. Configuración de Filtros de Investigación
    ESPECTRO = "K"
    M_MIN_JUP = 0.0001
    M_MAX_JUP = 2.0
    
    # 2. Iniciar cliente de procesamiento paralelo Dask
    print("Iniciando workers de Dask...")
    cliente_dask = Client(n_workers=4)
    
    # 3. Lanzar pipeline
    ejecutar_pipeline_completo(ESPECTRO, M_MIN_JUP, M_MAX_JUP, client=cliente_dask)
# Out:
# Iniciando workers de Dask...
# 📡 Consultando base de datos NASA... (Espectro: K)
#  Directorio raíz creado: Resultados_Estrellas_K
#
#  Procesando sistema: GJ_9827 (Masa: 0.62 M_sol)
#   -> Simulando planeta GJ 9827 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\GJ_9827\GJ_9827_b
#   -> Simulando planeta GJ 9827 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\GJ_9827\GJ_9827_c
#   -> Simulando planeta GJ 9827 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\GJ_9827\GJ_9827_d
#
#  Procesando sistema: HD_110067 (Masa: 0.798 M_sol)
#   -> Simulando planeta HD 110067 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_110067\HD_110067_b
#   -> Simulando planeta HD 110067 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_110067\HD_110067_c
#   -> Simulando planeta HD 110067 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_110067\HD_110067_d
#   -> Simulando planeta HD 110067 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_110067\HD_110067_e
#   -> Simulando planeta HD 110067 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_110067\HD_110067_f
#   -> Simulando planeta HD 110067 g ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_110067\HD_110067_g
#
#  Procesando sistema: HD_141399 (Masa: 1.07 M_sol)
#   -> Simulando planeta HD 141399 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_141399\HD_141399_e
#   -> Simulando planeta HD 141399 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_141399\HD_141399_d
#   -> Simulando planeta HD 141399 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_141399\HD_141399_b
#   -> Simulando planeta HD 141399 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_141399\HD_141399_c
#
#  Procesando sistema: HD_153557 (Masa: 0.79 M_sol)
#   -> Simulando planeta HD 153557 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_153557\HD_153557_b
#   -> Simulando planeta HD 153557 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_153557\HD_153557_c
#
#  Procesando sistema: HD_176986 (Masa: 0.789 M_sol)
#   -> Simulando planeta HD 176986 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_176986\HD_176986_c
#   -> Simulando planeta HD 176986 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_176986\HD_176986_b
#   -> Simulando planeta HD 176986 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_176986\HD_176986_d
#
#  Procesando sistema: HD_181433 (Masa: 0.86 M_sol)
#   -> Simulando planeta HD 181433 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_181433\HD_181433_b
#   -> Simulando planeta HD 181433 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_181433\HD_181433_d
#   -> Simulando planeta HD 181433 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_181433\HD_181433_c
#
#  Procesando sistema: HD_184010 (Masa: 1.35 M_sol)
#   -> Simulando planeta HD 184010 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_184010\HD_184010_c
#   -> Simulando planeta HD 184010 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_184010\HD_184010_d
#   -> Simulando planeta HD 184010 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_184010\HD_184010_b
#
#  Procesando sistema: HD_20781 (Masa: 0.7 M_sol)
#   -> Simulando planeta HD 20781 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_20781\HD_20781_b
#   -> Simulando planeta HD 20781 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_20781\HD_20781_c
#   -> Simulando planeta HD 20781 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_20781\HD_20781_e
#   -> Simulando planeta HD 20781 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_20781\HD_20781_d
#
#  Procesando sistema: HD_215152 (Masa: 0.77 M_sol)
#   -> Simulando planeta HD 215152 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_215152\HD_215152_e
#   -> Simulando planeta HD 215152 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_215152\HD_215152_c
#   -> Simulando planeta HD 215152 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_215152\HD_215152_d
#   -> Simulando planeta HD 215152 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_215152\HD_215152_b
#
#  Procesando sistema: HD_219134 (Masa: 0.81 M_sol)
#   -> Simulando planeta HD 219134 h ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_219134\HD_219134_h
#   -> Simulando planeta HD 219134 g ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_219134\HD_219134_g
#   -> Simulando planeta HD 219134 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_219134\HD_219134_b
#   -> Simulando planeta HD 219134 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_219134\HD_219134_d
#   -> Simulando planeta HD 219134 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_219134\HD_219134_f
#   -> Simulando planeta HD 219134 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_219134\HD_219134_c
#
#  Procesando sistema: HD_23472 (Masa: 0.67 M_sol)
#   -> Simulando planeta HD 23472 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_23472\HD_23472_b
#   -> Simulando planeta HD 23472 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_23472\HD_23472_c
#   -> Simulando planeta HD 23472 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_23472\HD_23472_f
#   -> Simulando planeta HD 23472 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_23472\HD_23472_d
#   -> Simulando planeta HD 23472 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_23472\HD_23472_e
#
#  Procesando sistema: HD_27894 (Masa: 0.81 M_sol)
#   -> Simulando planeta HD 27894 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_27894\HD_27894_b
#   -> Simulando planeta HD 27894 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_27894\HD_27894_c
#
#  Procesando sistema: HD_3167 (Masa: 0.864 M_sol)
#   -> Simulando planeta HD 3167 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_3167\HD_3167_b
#   -> Simulando planeta HD 3167 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_3167\HD_3167_c
#   -> Simulando planeta HD 3167 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_3167\HD_3167_d
#   -> Simulando planeta HD 3167 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_3167\HD_3167_e
#
#  Procesando sistema: HD_33142 (Masa: 1.52 M_sol)
#   -> Simulando planeta HD 33142 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_33142\HD_33142_c
#   -> Simulando planeta HD 33142 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_33142\HD_33142_b
#   -> Simulando planeta HD 33142 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_33142\HD_33142_d
#
#  Procesando sistema: HD_39194 (Masa: 0.86 M_sol)
#   -> Simulando planeta HD 39194 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_39194\HD_39194_b
#   -> Simulando planeta HD 39194 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_39194\HD_39194_c
#   -> Simulando planeta HD 39194 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_39194\HD_39194_d
#
#  Procesando sistema: HD_40307 (Masa: 0.77 M_sol)
#   -> Simulando planeta HD 40307 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_40307\HD_40307_b
#   -> Simulando planeta HD 40307 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_40307\HD_40307_c
#   -> Simulando planeta HD 40307 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_40307\HD_40307_d
#   -> Simulando planeta HD 40307 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_40307\HD_40307_f
#   -> Simulando planeta HD 40307 g ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_40307\HD_40307_g
#
#  Procesando sistema: HD_48948 (Masa: 0.686 M_sol)
#   -> Simulando planeta HD 48948 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_48948\HD_48948_b
#   -> Simulando planeta HD 48948 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_48948\HD_48948_c
#   -> Simulando planeta HD 48948 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_48948\HD_48948_d
#
#  Procesando sistema: HD_69830 (Masa: 0.86 M_sol)
#   -> Simulando planeta HD 69830 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_69830\HD_69830_c
#   -> Simulando planeta HD 69830 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_69830\HD_69830_b
#   -> Simulando planeta HD 69830 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_69830\HD_69830_d
#
#  Procesando sistema: HD_7924 (Masa: 0.65 M_sol)
#   -> Simulando planeta HD 7924 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_7924\HD_7924_d
#   -> Simulando planeta HD 7924 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_7924\HD_7924_b
#   -> Simulando planeta HD 7924 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HD_7924\HD_7924_c
#
#  Procesando sistema: HIP_57274 (Masa: 0.29 M_sol)
#   -> Simulando planeta HIP 57274 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HIP_57274\HIP_57274_b
#   -> Simulando planeta HIP 57274 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HIP_57274\HIP_57274_d
#   -> Simulando planeta HIP 57274 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\HIP_57274\HIP_57274_c
#
#  Procesando sistema: K2-136 (Masa: 0.742 M_sol)
#   -> Simulando planeta K2-136 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-136\K2-136_c
#   -> Simulando planeta K2-136 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-136\K2-136_b
#   -> Simulando planeta K2-136 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-136\K2-136_d
#
#  Procesando sistema: K2-155 (Masa: 0.65 M_sol)
#   -> Simulando planeta K2-155 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-155\K2-155_c
#   -> Simulando planeta K2-155 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-155\K2-155_d
#   -> Simulando planeta K2-155 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-155\K2-155_b
#
#  Procesando sistema: K2-16 (Masa: 0.68 M_sol)
#   -> Simulando planeta K2-16 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-16\K2-16_b
#   -> Simulando planeta K2-16 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-16\K2-16_c
#   [!] Saltando EPIC 201754305 d (Falta parámetro de distancia orbital)
#
#  Procesando sistema: K2-233 (Masa: 0.79 M_sol)
#   -> Simulando planeta K2-233 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-233\K2-233_d
#   -> Simulando planeta K2-233 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-233\K2-233_c
#   -> Simulando planeta K2-233 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-233\K2-233_b
#
#  Procesando sistema: K2-285 (Masa: 0.83 M_sol)
#   -> Simulando planeta K2-285 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-285\K2-285_b
#   -> Simulando planeta K2-285 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-285\K2-285_c
#   -> Simulando planeta K2-285 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-285\K2-285_e
#   -> Simulando planeta K2-285 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\K2-285\K2-285_d
#
#  Procesando sistema: Kepler-158 (Masa: 0.656 M_sol)
#   -> Simulando planeta Kepler-158 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-158\Kepler-158_b
#   [!] Saltando Kepler-158 d (Falta parámetro de distancia orbital)
#   -> Simulando planeta Kepler-158 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-158\Kepler-158_c
#
#  Procesando sistema: Kepler-167 (Masa: 0.777 M_sol)
#   -> Simulando planeta Kepler-167 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-167\Kepler-167_d
#   -> Simulando planeta Kepler-167 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-167\Kepler-167_e
#   -> Simulando planeta Kepler-167 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-167\Kepler-167_c
#   -> Simulando planeta Kepler-167 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-167\Kepler-167_b
#
#  Procesando sistema: Kepler-247 (Masa: 0.887 M_sol)
#   -> Simulando planeta Kepler-247 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-247\Kepler-247_d
#   -> Simulando planeta Kepler-247 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-247\Kepler-247_b
#   [!] Saltando KOI-884 e (Falta parámetro de distancia orbital)
#   -> Simulando planeta Kepler-247 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-247\Kepler-247_c
#
#  Procesando sistema: Kepler-411 (Masa: 0.87 M_sol)
#   -> Simulando planeta Kepler-411 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-411\Kepler-411_e
#   -> Simulando planeta Kepler-411 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-411\Kepler-411_c
#   -> Simulando planeta Kepler-411 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-411\Kepler-411_b
#   -> Simulando planeta Kepler-411 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-411\Kepler-411_d
#
#  Procesando sistema: Kepler-444 (Masa: 0.758 M_sol)
#   -> Simulando planeta Kepler-444 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-444\Kepler-444_c
#   -> Simulando planeta Kepler-444 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-444\Kepler-444_f
#   -> Simulando planeta Kepler-444 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-444\Kepler-444_b
#   -> Simulando planeta Kepler-444 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-444\Kepler-444_e
#   -> Simulando planeta Kepler-444 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-444\Kepler-444_d
#
#  Procesando sistema: Kepler-46 (Masa: 0.883 M_sol)
#   -> Simulando planeta Kepler-46 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-46\Kepler-46_c
#   -> Simulando planeta Kepler-46 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-46\Kepler-46_d
#
#  Procesando sistema: Kepler-62 (Masa: 0.69 M_sol)
#   -> Simulando planeta Kepler-62 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-62\Kepler-62_f
#   -> Simulando planeta Kepler-62 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-62\Kepler-62_c
#   -> Simulando planeta Kepler-62 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-62\Kepler-62_d
#   -> Simulando planeta Kepler-62 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-62\Kepler-62_b
#   -> Simulando planeta Kepler-62 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-62\Kepler-62_e
#
#  Procesando sistema: Kepler-80 (Masa: 0.83 M_sol)
#   -> Simulando planeta Kepler-80 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-80\Kepler-80_c
#   -> Simulando planeta Kepler-80 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-80\Kepler-80_e
#   [!] Saltando Kepler-80 g (Falta parámetro de distancia orbital)
#   -> Simulando planeta Kepler-80 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-80\Kepler-80_d
#   -> Simulando planeta Kepler-80 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\Kepler-80\Kepler-80_b
#
#  Procesando sistema: TOI-1246 (Masa: 0.8889 M_sol)
#   -> Simulando planeta TOI-1246 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-1246\TOI-1246_d
#   -> Simulando planeta TOI-1246 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-1246\TOI-1246_b
#   -> Simulando planeta TOI-1246 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-1246\TOI-1246_c
#   -> Simulando planeta TOI-1246 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-1246\TOI-1246_e
#
#  Procesando sistema: TOI-125 (Masa: 0.859 M_sol)
#   -> Simulando planeta TOI-125 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-125\TOI-125_b
#   -> Simulando planeta TOI-125 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-125\TOI-125_c
#   -> Simulando planeta TOI-125 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-125\TOI-125_d
#
#  Procesando sistema: TOI-1260 (Masa: 0.679 M_sol)
#   -> Simulando planeta TOI-1260 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-1260\TOI-1260_c
#   -> Simulando planeta TOI-1260 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-1260\TOI-1260_d
#   -> Simulando planeta TOI-1260 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-1260\TOI-1260_b
#
#  Procesando sistema: TOI-178 (Masa: 0.647 M_sol)
#   -> Simulando planeta TOI-178 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-178\TOI-178_b
#   -> Simulando planeta TOI-178 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-178\TOI-178_c
#   -> Simulando planeta TOI-178 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-178\TOI-178_d
#   -> Simulando planeta TOI-178 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-178\TOI-178_e
#   -> Simulando planeta TOI-178 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-178\TOI-178_f
#   -> Simulando planeta TOI-178 g ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-178\TOI-178_g
#
#  Procesando sistema: TOI-2076 (Masa: 0.849 M_sol)
#   -> Simulando planeta TOI-2076 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-2076\TOI-2076_e
#   -> Simulando planeta TOI-2076 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-2076\TOI-2076_b
#   -> Simulando planeta TOI-2076 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-2076\TOI-2076_c
#   -> Simulando planeta TOI-2076 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-2076\TOI-2076_d
#
#  Procesando sistema: TOI-4010 (Masa: 0.88 M_sol)
#   -> Simulando planeta TOI-4010 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-4010\TOI-4010_c
#   -> Simulando planeta TOI-4010 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-4010\TOI-4010_d
#   -> Simulando planeta TOI-4010 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-4010\TOI-4010_b
#
#  Procesando sistema: TOI-4504 (Masa: 0.875 M_sol)
#   -> Simulando planeta TOI-4504 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-4504\TOI-4504_b
#
#  Procesando sistema: TOI-500 (Masa: 0.74 M_sol)
#   -> Simulando planeta TOI-500 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-500\TOI-500_b
#   [!] Saltando TOI-500 c (Falta parámetro de distancia orbital)
#   [!] Saltando TOI-500 d (Falta parámetro de distancia orbital)
#   [!] Saltando TOI-500 e (Falta parámetro de distancia orbital)
#
#  Procesando sistema: TOI-5789 (Masa: 0.821 M_sol)
#   -> Simulando planeta TOI-5789 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-5789\TOI-5789_c
#   -> Simulando planeta TOI-5789 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-5789\TOI-5789_d
#   -> Simulando planeta TOI-5789 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-5789\TOI-5789_b
#   -> Simulando planeta TOI-5789 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-5789\TOI-5789_e
#
#  Procesando sistema: TOI-712 (Masa: 0.732 M_sol)
#   -> Simulando planeta TOI-712 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-712\TOI-712_c
#   -> Simulando planeta TOI-712 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-712\TOI-712_d
#   -> Simulando planeta TOI-712 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\TOI-712\TOI-712_b
#
#  Procesando sistema: V1298_Tau (Masa: 1.1 M_sol)
#   -> Simulando planeta V1298 Tau b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\V1298_Tau\V1298_Tau_b
#   -> Simulando planeta V1298 Tau c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\V1298_Tau\V1298_Tau_c
#   -> Simulando planeta V1298 Tau d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\V1298_Tau\V1298_Tau_d
#   -> Simulando planeta V1298 Tau e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\V1298_Tau\V1298_Tau_e
#
#  Procesando sistema: WASP-132 (Masa: 0.789 M_sol)
#   -> Simulando planeta WASP-132 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\WASP-132\WASP-132_b
#   -> Simulando planeta WASP-132 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_K\WASP-132\WASP-132_c

# %%
if __name__ == "__main__":
    # 1. Configuración de Filtros de Investigación
    ESPECTRO = "M"
    M_MIN_JUP = 0.0001
    M_MAX_JUP = 2.0
    
    # 2. Iniciar cliente de procesamiento paralelo Dask
    print("Iniciando workers de Dask...")
    cliente_dask = Client(n_workers=4)
    
    # 3. Lanzar pipeline
    ejecutar_pipeline_completo(ESPECTRO, M_MIN_JUP, M_MAX_JUP, client=cliente_dask)
# Out:
# Iniciando workers de Dask...
# 📡 Consultando base de datos NASA... (Espectro: M)
#  Directorio raíz creado: Resultados_Estrellas_M
#
#  Procesando sistema: 55_Cnc_B (Masa: 0.26 M_sol)
#   -> Simulando planeta 55 Cnc B b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\55_Cnc_B\55_Cnc_B_b
#   -> Simulando planeta 55 Cnc B c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\55_Cnc_B\55_Cnc_B_c
#
#  Procesando sistema: AU_Mic (Masa: 0.635 M_sol)
#   [!] Saltando AU Mic e (Falta parámetro de distancia orbital)
#   [!] Saltando AU Mic d (Falta parámetro de distancia orbital)
#   -> Simulando planeta AU Mic b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\AU_Mic\AU_Mic_b
#   -> Simulando planeta AU Mic c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\AU_Mic\AU_Mic_c
#
#  Procesando sistema: Barnard's_star (Masa: 0.162 M_sol)
#   -> Simulando planeta Barnard d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Barnard's_star\Barnard_d
#   -> Simulando planeta Barnard c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Barnard's_star\Barnard_c
#   -> Simulando planeta Barnard b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Barnard's_star\Barnard_b
#   -> Simulando planeta Barnard e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Barnard's_star\Barnard_e
#
#  Procesando sistema: GJ_1061 (Masa: 0.12 M_sol)
#   -> Simulando planeta GJ 1061 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_1061\GJ_1061_d
#   -> Simulando planeta GJ 1061 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_1061\GJ_1061_b
#   -> Simulando planeta GJ 1061 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_1061\GJ_1061_c
#
#  Procesando sistema: GJ_163 (Masa: 0.4 M_sol)
#   -> Simulando planeta GJ 163 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_163\GJ_163_c
#   -> Simulando planeta GJ 163 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_163\GJ_163_d
#   -> Simulando planeta GJ 163 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_163\GJ_163_b
#
#  Procesando sistema: GJ_180 (Masa: 0.43 M_sol)
#   -> Simulando planeta GJ 180 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_180\GJ_180_d
#   -> Simulando planeta GJ 180 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_180\GJ_180_b
#   -> Simulando planeta GJ 180 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_180\GJ_180_c
#
#  Procesando sistema: GJ_3138 (Masa: 0.681 M_sol)
#   -> Simulando planeta GJ 3138 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_3138\GJ_3138_b
#   -> Simulando planeta GJ 3138 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_3138\GJ_3138_d
#   -> Simulando planeta GJ 3138 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_3138\GJ_3138_c
#
#  Procesando sistema: GJ_3293 (Masa: 0.42 M_sol)
#   -> Simulando planeta GJ 3293 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_3293\GJ_3293_c
#   -> Simulando planeta GJ 3293 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_3293\GJ_3293_b
#   -> Simulando planeta GJ 3293 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_3293\GJ_3293_e
#   -> Simulando planeta GJ 3293 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_3293\GJ_3293_d
#
#  Procesando sistema: GJ_357 (Masa: 0.342 M_sol)
#   -> Simulando planeta GJ 357 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_357\GJ_357_b
#   -> Simulando planeta GJ 357 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_357\GJ_357_c
#   -> Simulando planeta GJ 357 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_357\GJ_357_d
#
#  Procesando sistema: GJ_367 (Masa: 0.451 M_sol)
#   -> Simulando planeta GJ 367 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_367\GJ_367_b
#   [!] Saltando GJ 367 c (Falta parámetro de distancia orbital)
#   [!] Saltando GJ 367 d (Falta parámetro de distancia orbital)
#
#  Procesando sistema: GJ_3998 (Masa: 0.52 M_sol)
#   -> Simulando planeta GJ 3998 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_3998\GJ_3998_d
#   -> Simulando planeta GJ 3998 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_3998\GJ_3998_b
#   -> Simulando planeta GJ 3998 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_3998\GJ_3998_c
#
#  Procesando sistema: GJ_433 (Masa: 0.48 M_sol)
#   -> Simulando planeta GJ 433 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_433\GJ_433_b
#   -> Simulando planeta GJ 433 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_433\GJ_433_d
#   -> Simulando planeta GJ 433 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_433\GJ_433_c
#
#  Procesando sistema: GJ_581 (Masa: 0.295 M_sol)
#   -> Simulando planeta GJ 581 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_581\GJ_581_b
#   -> Simulando planeta GJ 581 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_581\GJ_581_c
#   -> Simulando planeta GJ 581 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_581\GJ_581_e
#
#  Procesando sistema: GJ_667_C (Masa: 0.33 M_sol)
#   -> Simulando planeta GJ 667 C f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_667_C\GJ_667_C_f
#   -> Simulando planeta GJ 667 C b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_667_C\GJ_667_C_b
#   -> Simulando planeta GJ 667 C c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_667_C\GJ_667_C_c
#   -> Simulando planeta GJ 667 C e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_667_C\GJ_667_C_e
#   -> Simulando planeta GJ 667 C g ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_667_C\GJ_667_C_g
#
#  Procesando sistema: GJ_676_A (Masa: 0.626 M_sol)
#   -> Simulando planeta GJ 676 A e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_676_A\GJ_676_A_e
#   -> Simulando planeta GJ 676 A d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_676_A\GJ_676_A_d
#
#  Procesando sistema: GJ_876 (Masa: 0.32 M_sol)
#   -> Simulando planeta GJ 876 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_876\GJ_876_c
#   -> Simulando planeta GJ 876 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_876\GJ_876_d
#   -> Simulando planeta GJ 876 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_876\GJ_876_e
#
#  Procesando sistema: GJ_887 (Masa: 0.495 M_sol)
#   -> Simulando planeta GJ 887 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_887\GJ_887_e
#   -> Simulando planeta GJ 887 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_887\GJ_887_c
#   -> Simulando planeta GJ 887 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_887\GJ_887_b
#   -> Simulando planeta GJ 887 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\GJ_887\GJ_887_d
#
#  Procesando sistema: K2-133 (Masa: 0.461 M_sol)
#   -> Simulando planeta K2-133 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\K2-133\K2-133_c
#   -> Simulando planeta K2-133 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\K2-133\K2-133_d
#   -> Simulando planeta K2-133 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\K2-133\K2-133_e
#   -> Simulando planeta K2-133 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\K2-133\K2-133_b
#
#  Procesando sistema: K2-239 (Masa: 0.4 M_sol)
#   -> Simulando planeta K2-239 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\K2-239\K2-239_c
#   -> Simulando planeta K2-239 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\K2-239\K2-239_b
#   -> Simulando planeta K2-239 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\K2-239\K2-239_d
#
#  Procesando sistema: K2-3 (Masa: 0.549 M_sol)
#   -> Simulando planeta K2-3 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\K2-3\K2-3_d
#   -> Simulando planeta K2-3 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\K2-3\K2-3_c
#   -> Simulando planeta K2-3 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\K2-3\K2-3_b
#
#  Procesando sistema: K2-384 (Masa: 0.33 M_sol)
#   [!] Saltando K2-384 f (Falta parámetro de distancia orbital)
#   [!] Saltando K2-384 e (Falta parámetro de distancia orbital)
#   [!] Saltando K2-384 d (Falta parámetro de distancia orbital)
#   [!] Saltando K2-384 c (Falta parámetro de distancia orbital)
#   [!] Saltando K2-384 b (Falta parámetro de distancia orbital)
#
#  Procesando sistema: Kepler-114 (Masa: 0.56 M_sol)
#   -> Simulando planeta Kepler-114 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-114\Kepler-114_b
#   -> Simulando planeta Kepler-114 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-114\Kepler-114_c
#   -> Simulando planeta Kepler-114 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-114\Kepler-114_d
#
#  Procesando sistema: Kepler-138 (Masa: 0.535 M_sol)
#   -> Simulando planeta Kepler-138 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-138\Kepler-138_e
#   -> Simulando planeta Kepler-138 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-138\Kepler-138_b
#   -> Simulando planeta Kepler-138 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-138\Kepler-138_c
#   -> Simulando planeta Kepler-138 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-138\Kepler-138_d
#
#  Procesando sistema: Kepler-186 (Masa: 0.544 M_sol)
#   -> Simulando planeta Kepler-186 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-186\Kepler-186_b
#   -> Simulando planeta Kepler-186 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-186\Kepler-186_e
#   -> Simulando planeta Kepler-186 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-186\Kepler-186_c
#   -> Simulando planeta Kepler-186 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-186\Kepler-186_d
#   -> Simulando planeta Kepler-186 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-186\Kepler-186_f
#
#  Procesando sistema: Kepler-235 (Masa: 0.581 M_sol)
#   -> Simulando planeta Kepler-235 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-235\Kepler-235_b
#   -> Simulando planeta Kepler-235 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-235\Kepler-235_d
#   -> Simulando planeta Kepler-235 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-235\Kepler-235_e
#   -> Simulando planeta Kepler-235 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-235\Kepler-235_c
#
#  Procesando sistema: Kepler-249 (Masa: 0.510238 M_sol)
#   -> Simulando planeta Kepler-249 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-249\Kepler-249_b
#   -> Simulando planeta Kepler-249 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-249\Kepler-249_d
#   -> Simulando planeta Kepler-249 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-249\Kepler-249_c
#
#  Procesando sistema: Kepler-26 (Masa: 0.544 M_sol)
#   -> Simulando planeta Kepler-26 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-26\Kepler-26_e
#   -> Simulando planeta Kepler-26 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-26\Kepler-26_b
#   -> Simulando planeta Kepler-26 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-26\Kepler-26_c
#   -> Simulando planeta Kepler-26 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-26\Kepler-26_d
#
#  Procesando sistema: Kepler-267 (Masa: 0.541571 M_sol)
#   -> Simulando planeta Kepler-267 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-267\Kepler-267_b
#   -> Simulando planeta Kepler-267 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-267\Kepler-267_c
#   -> Simulando planeta Kepler-267 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-267\Kepler-267_d
#
#  Procesando sistema: Kepler-296 (Masa: 0.498 M_sol)
#   -> Simulando planeta Kepler-296 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-296\Kepler-296_f
#   -> Simulando planeta Kepler-296 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-296\Kepler-296_b
#   -> Simulando planeta Kepler-296 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-296\Kepler-296_d
#   -> Simulando planeta Kepler-296 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-296\Kepler-296_e
#   -> Simulando planeta Kepler-296 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-296\Kepler-296_c
#
#  Procesando sistema: Kepler-32 (Masa: 0.58 M_sol)
#   -> Simulando planeta Kepler-32 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-32\Kepler-32_e
#   -> Simulando planeta Kepler-32 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-32\Kepler-32_d
#   -> Simulando planeta Kepler-32 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-32\Kepler-32_c
#
#  Procesando sistema: Kepler-42 (Masa: 0.13 M_sol)
#   -> Simulando planeta Kepler-42 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-42\Kepler-42_b
#   -> Simulando planeta Kepler-42 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-42\Kepler-42_c
#   -> Simulando planeta Kepler-42 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-42\Kepler-42_d
#
#  Procesando sistema: Kepler-445 (Masa: 0.18 M_sol)
#   -> Simulando planeta Kepler-445 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-445\Kepler-445_d
#   -> Simulando planeta Kepler-445 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-445\Kepler-445_c
#   -> Simulando planeta Kepler-445 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-445\Kepler-445_b
#
#  Procesando sistema: Kepler-446 (Masa: 0.22 M_sol)
#   -> Simulando planeta Kepler-446 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-446\Kepler-446_c
#   -> Simulando planeta Kepler-446 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-446\Kepler-446_b
#   -> Simulando planeta Kepler-446 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-446\Kepler-446_d
#
#  Procesando sistema: Kepler-49 (Masa: 0.607 M_sol)
#   -> Simulando planeta Kepler-49 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-49\Kepler-49_b
#   -> Simulando planeta Kepler-49 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-49\Kepler-49_e
#   -> Simulando planeta Kepler-49 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-49\Kepler-49_c
#   -> Simulando planeta Kepler-49 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-49\Kepler-49_d
#
#  Procesando sistema: Kepler-52 (Masa: 0.577 M_sol)
#   -> Simulando planeta Kepler-52 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-52\Kepler-52_c
#   -> Simulando planeta Kepler-52 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-52\Kepler-52_d
#   -> Simulando planeta Kepler-52 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-52\Kepler-52_b
#
#  Procesando sistema: Kepler-54 (Masa: 0.518 M_sol)
#   -> Simulando planeta Kepler-54 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-54\Kepler-54_c
#   -> Simulando planeta Kepler-54 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-54\Kepler-54_b
#   -> Simulando planeta Kepler-54 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-54\Kepler-54_d
#
#  Procesando sistema: Kepler-81 (Masa: 0.64 M_sol)
#   -> Simulando planeta Kepler-81 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-81\Kepler-81_d
#   -> Simulando planeta Kepler-81 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-81\Kepler-81_b
#   -> Simulando planeta Kepler-81 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-81\Kepler-81_c
#
#  Procesando sistema: Kepler-83 (Masa: 0.66 M_sol)
#   -> Simulando planeta Kepler-83 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-83\Kepler-83_c
#   -> Simulando planeta Kepler-83 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-83\Kepler-83_b
#   -> Simulando planeta Kepler-83 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Kepler-83\Kepler-83_d
#
#  Procesando sistema: L_98-59 (Masa: 0.2923 M_sol)
#   -> Simulando planeta L 98-59 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\L_98-59\L_98-59_f
#   -> Simulando planeta L 98-59 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\L_98-59\L_98-59_b
#   -> Simulando planeta L 98-59 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\L_98-59\L_98-59_c
#   -> Simulando planeta L 98-59 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\L_98-59\L_98-59_d
#   -> Simulando planeta L 98-59 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\L_98-59\L_98-59_e
#
#  Procesando sistema: LHS_1678 (Masa: 0.345 M_sol)
#   -> Simulando planeta LHS 1678 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\LHS_1678\LHS_1678_c
#   -> Simulando planeta LHS 1678 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\LHS_1678\LHS_1678_d
#   -> Simulando planeta LHS 1678 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\LHS_1678\LHS_1678_b
#
#  Procesando sistema: LHS_1903 (Masa: 0.538 M_sol)
#   -> Simulando planeta LHS 1903 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\LHS_1903\LHS_1903_d
#   -> Simulando planeta LHS 1903 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\LHS_1903\LHS_1903_e
#   -> Simulando planeta LHS 1903 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\LHS_1903\LHS_1903_b
#   -> Simulando planeta LHS 1903 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\LHS_1903\LHS_1903_c
#
#  Procesando sistema: LP_791-18 (Masa: 0.139 M_sol)
#   -> Simulando planeta LP 791-18 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\LP_791-18\LP_791-18_b
#   -> Simulando planeta LP 791-18 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\LP_791-18\LP_791-18_c
#   -> Simulando planeta LP 791-18 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\LP_791-18\LP_791-18_d
#
#  Procesando sistema: TOI-1266 (Masa: 0.437 M_sol)
#   -> Simulando planeta TOI-1266 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-1266\TOI-1266_d
#   -> Simulando planeta TOI-1266 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-1266\TOI-1266_b
#   -> Simulando planeta TOI-1266 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-1266\TOI-1266_c
#
#  Procesando sistema: TOI-1749 (Masa: 0.58 M_sol)
#   -> Simulando planeta TOI-1749 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-1749\TOI-1749_c
#   -> Simulando planeta TOI-1749 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-1749\TOI-1749_b
#   -> Simulando planeta TOI-1749 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-1749\TOI-1749_d
#
#  Procesando sistema: TOI-2267_A (Masa: 0.171 M_sol)
#   -> Simulando planeta TOI-2267 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-2267_A\TOI-2267_c
#   -> Simulando planeta TOI-2267 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-2267_A\TOI-2267_b
#
#  Procesando sistema: TOI-2267_B (Masa: 0.0989 M_sol)
#   -> Simulando planeta TOI-2267 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-2267_B\TOI-2267_d
#
#  Procesando sistema: TOI-270 (Masa: 0.386 M_sol)
#   -> Simulando planeta TOI-270 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-270\TOI-270_b
#   -> Simulando planeta TOI-270 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-270\TOI-270_c
#   -> Simulando planeta TOI-270 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-270\TOI-270_d
#
#  Procesando sistema: TOI-663 (Masa: 0.514 M_sol)
#   -> Simulando planeta TOI-663 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-663\TOI-663_c
#   -> Simulando planeta TOI-663 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-663\TOI-663_b
#   -> Simulando planeta TOI-663 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-663\TOI-663_d
#
#  Procesando sistema: TOI-700 (Masa: 0.415 M_sol)
#   -> Simulando planeta TOI-700 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-700\TOI-700_b
#   -> Simulando planeta TOI-700 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-700\TOI-700_c
#   -> Simulando planeta TOI-700 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-700\TOI-700_d
#   -> Simulando planeta TOI-700 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TOI-700\TOI-700_e
#
#  Procesando sistema: TRAPPIST-1 (Masa: 0.0898 M_sol)
#   -> Simulando planeta TRAPPIST-1 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TRAPPIST-1\TRAPPIST-1_b
#   -> Simulando planeta TRAPPIST-1 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TRAPPIST-1\TRAPPIST-1_c
#   -> Simulando planeta TRAPPIST-1 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TRAPPIST-1\TRAPPIST-1_d
#   -> Simulando planeta TRAPPIST-1 e ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TRAPPIST-1\TRAPPIST-1_e
#   -> Simulando planeta TRAPPIST-1 f ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TRAPPIST-1\TRAPPIST-1_f
#   -> Simulando planeta TRAPPIST-1 g ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TRAPPIST-1\TRAPPIST-1_g
#   -> Simulando planeta TRAPPIST-1 h ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\TRAPPIST-1\TRAPPIST-1_h
#
#  Procesando sistema: Teegarden's_Star (Masa: 0.097 M_sol)
#   -> Simulando planeta Teegarden's Star c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Teegarden's_Star\Teegarden's_Star_c
#   -> Simulando planeta Teegarden's Star d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Teegarden's_Star\Teegarden's_Star_d
#   -> Simulando planeta Teegarden's Star b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Teegarden's_Star\Teegarden's_Star_b
#
#  Procesando sistema: Wolf_1061 (Masa: 0.294 M_sol)
#   -> Simulando planeta Wolf 1061 b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Wolf_1061\Wolf_1061_b
#   -> Simulando planeta Wolf 1061 c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Wolf_1061\Wolf_1061_c
#   -> Simulando planeta Wolf 1061 d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\Wolf_1061\Wolf_1061_d
#
#  Procesando sistema: YZ_Cet (Masa: 0.142 M_sol)
#   -> Simulando planeta YZ Cet b ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\YZ_Cet\YZ_Cet_b
#   -> Simulando planeta YZ Cet c ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\YZ_Cet\YZ_Cet_c
#   -> Simulando planeta YZ Cet d ...
#   -> ✔️ Resultados guardados en: Resultados_Estrellas_M\YZ_Cet\YZ_Cet_d
